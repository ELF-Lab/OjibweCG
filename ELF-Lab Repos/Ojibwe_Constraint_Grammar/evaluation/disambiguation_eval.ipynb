# %% [markdown]
# ## Evaluation for Disambiguation
# The evaluation for disambiguation will be split up into three stages, with the first and the last done in this notebook:
# 1) Parsing the evaluation set
# 2) Creating the gold standard from the eval set (done by hand)
# 3) Evaluating the model on the gold standard

# %% [markdown]
# ### Parsing the evaluation set
# For our evaluation set, we will be using a sample of 4646 example sentences from the OPD, of which we will sample sentences that are fully analyzed by the FST (but could contain no ambiguities).
#
# The code used to sample the tsv file and create the evaluation set lives in `disamb.py`.

# %%
# setup and imports
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from pathlib import Path
from evaluation.disamb import read_opd_tsv, build_eval_sample, write_eval_artifacts

TSV_PATH = Path("../data/eval/example_sentences.tsv")
FST_BINARY_PATH = Path("../data/fst/ojibwe7.fomabin")
OUTDIR = Path("sample_disambig")

# read tsv
rows = read_opd_tsv(TSV_PATH)
# build the evaluation set with random seed
keep = build_eval_sample(rows, FST_BINARY_PATH, sample_size=300, seed=421)
# write the evaluation sample sets
write_eval_artifacts(keep, FST_BINARY_PATH, OUTDIR, write_100=True)

print("Wrote files:",
      OUTDIR / "sample_100.tsv",
      OUTDIR / "sample_100.txt",
      OUTDIR / "sample_300.tsv",
      OUTDIR / "sample_300.txt",
      sep="\n")
# Out:
# FST file is ../data/fst/ojibwe7.fomabin
# FST file is ../data/fst/ojibwe7.fomabin
# Wrote files:
# eval_data/sample_100.tsv
# eval_data/sample_100.txt
# eval_data/sample_300.tsv
# eval_data/sample_300.txt

# %% [markdown]
# ### Creating the gold standard
#
# The gold standard was created by doing disambiguation by hand on the sample sets parsed above. Unwanted lines were deleted from the .cg3 file by hand, as if the human was the disambiguation module.

# %% [markdown]
# When manually disambiguating the sentences parsed above, the person analyzing the sentences (who is a speaker of Ojibwe) mentioned that sentence #30 of the subset was an ungrammatical Ojibwe sentence. Therefore, we will take sentence #300 (since we parsed 300 sentences above) to fill this hole in.

# %% [markdown]
# ### Evaluating the model on the gold standard
#
# Will be done once the gold standard is ready.
