# %%
# Make sure my changes work
from grammar_modules.disambiguation import disambiguate, get_disambiguation_path
from grammar_modules.fst import load_fst_parser

sentence = "awedi mitig"
cg3 = get_disambiguation_path()
fst = load_fst_parser()

disambiguate(sentence, cg3, fst, verbose=True)
# Out:
# FST file is /Users/matthias/ELF-Lab Repos/Ojibwe_Constraint_Grammar/data/fst/ojibwe7.fomabin
# <function get_disambiguation_path at 0x10e5be020>
